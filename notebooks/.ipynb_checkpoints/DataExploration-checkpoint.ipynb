# %%
import pandas as pd
import numpy as np
import csv, matplotlib
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from collections import Counter
import matplotlib.pyplot as plt
from dateutil.parser import parse
# %matplotlib inline

# %% [markdown]
# ### Some Utility functions

# %%
def getSentiment(sentence):
    '''
    This function will return polarity 
    scores given a sentence
    '''
    sid = SentimentIntensityAnalyzer()
    ps = sid.polarity_scores(str(sentence))
    return str(ps['compound'])

def parseUrl(url):
    '''
    This function returns categories in a url string
    '''
    return url.split('/')[2:5]

def getCategory(url):
    '''
    Extract category from url
    '''
    return parseUrl(url)[1]

def getCategory2(url):
    '''
    Extract sub category from url
    '''
    result = parseUrl(url)[2]
    if '-' in result:
        return '-'
    return result

def toDateObj(stri):
    try:
        return parse(stri)
    except:
        return None

# %% [markdown]
# ### load data into pandas

# %%
data = pd.read_csv('NationMediaArticles.csv')
data.head()
# Out:
#                          date  \
# 0     May 21, 2015 at 07:11PM
# 1     May 21, 2015 at 10:24PM
# 2  August 28, 2015 at 07:16PM
# 3  August 28, 2015 at 07:20PM
# 4  August 28, 2015 at 07:23PM
#
#                                             headline  \
# 0  Kenya loses over Sh600bn every year in tax eva...
# 1      Fight hard, Munya told after winning top seat
# 2  How we clinched deal to supply veges to superm...
# 3  Online fraudster leaves my lovely friends high...
# 4  Mrenda is a revered vegetable at the Kakuma Re...
#
#                                            paragraph  \
# 0  Kenya loses an estimated Sh639 billion annuall...
# 1  Mr Mvurya bowed out of the race after the gove...
# 2  The group brings together over 2,400 farmers w...
# 3  The chama, which largely operates on WhatsApp,...
# 4  The farm ran by refugees is easy to pick out f...
#
#                                                  url  \
# 0  http://www.nation.co.ke/business/Kenya-loses-o...
# 1  http://www.nation.co.ke/news/politics/Tough-ta...
# 2  http://www.nation.co.ke/business/seedsofgold/H...
# 3  http://www.nation.co.ke/business/seedsofgold/O...
# 4  http://www.nation.co.ke/business/seedsofgold/-...
#
#                          source
# 0  Daily Nation RSS Feeds: Home
# 1  Daily Nation RSS Feeds: Home
# 2           Daily Nation | Home
# 3           Daily Nation | Home
# 4           Daily Nation | Home

# %% [markdown]
# ### Sort by dates

# %%
data['datetime'] = data['date'].apply(toDateObj)
data.sort_values(by='datetime')
data.tail()
# Out:
#                                date  \
# 61003  November 22, 2014 at 04:22PM
# 61004  November 22, 2014 at 04:39PM
# 61005  November 22, 2014 at 12:06PM
# 61006  November 22, 2014 at 06:33PM
# 61007  November 22, 2014 at 08:38AM
#
#                                                 headline  \
# 61003  LeBron James frustrated as struggling Cavalier...
# 61004  Bodies of 28 Shabaab attack victims in Mandera...
# 61005       Death toll from Marsabit clashes rises to 10
# 61006  Survivor says Al-Shabaab gunmen fired in jubil...
# 61007  At least 28 killed in suspected Shabaab attack...
#
#                                                paragraph  \
# 61003  Struggling to come together with consistent te...
# 61004  Police said none of the 28 who died in the Al-...
# 61005  The death toll from the Wednesday clashes betw...
# 61006  One of passengers who survived the attack said...
# 61007  Initial reports indicated that about a 100 arm...
#
#                                                      url  \
# 61003  http://www.nation.co.ke/sports/Basketball/LeBr...
# 61004  http://www.nation.co.ke/counties/Bodies-28-Sha...
# 61005  http://www.nation.co.ke/counties/Death-toll-fr...
# 61006  http://www.nation.co.ke/counties/-/1107872/253...
# 61007  http://www.nation.co.ke/counties/28-dead-suspe...
#
#                              source            datetime
# 61003  Daily Nation RSS Feeds: Home 2014-11-22 16:22:00
# 61004  Daily Nation RSS Feeds: Home 2014-11-22 16:39:00
# 61005  Daily Nation RSS Feeds: Home 2014-11-22 12:06:00
# 61006  Daily Nation RSS Feeds: Home 2014-11-22 18:33:00
# 61007  Daily Nation RSS Feeds: Home 2014-11-22 08:38:00

# %% [markdown]
# ### Get politics sub category

# %%
data['category'] = data['url'].apply(getCategory)
data['subCategory'] = data['url'].apply(getCategory2)
news = data[data['subCategory'].isin(['politics'])].copy()
news.head()
# Out:
#                           date  \
# 1      May 21, 2015 at 10:24PM
# 9   August 28, 2015 at 08:57PM
# 11  August 28, 2015 at 09:22PM
# 15  August 28, 2015 at 09:28PM
# 16  August 28, 2015 at 09:34PM
#
#                                              headline  \
# 1       Fight hard, Munya told after winning top seat
# 9                  Governors warn of anti-county laws
# 11        John Mbadi: We needed Raila Odinga in House
# 15  Government business now managed in an organise...
# 16       How Kenya is changing under new Constitution
#
#                                             paragraph  \
# 1   Mr Mvurya bowed out of the race after the gove...
# 9   AG office auditing the implementation of the c...
# 11  Previously, presidential election losers had t...
# 15  Senate and National Assembly have recognised l...
# 16  The era of when the President could hire and f...
#
#                                                   url  \
# 1   http://www.nation.co.ke/news/politics/Tough-ta...
# 9   http://www.nation.co.ke/news/politics/Governor...
# 11  http://www.nation.co.ke/news/politics/Raila-Od...
# 15  http://www.nation.co.ke/news/politics/Governme...
# 16  http://www.nation.co.ke/news/politics/Kenya-Co...
#
#                           source            datetime category subCategory
# 1   Daily Nation RSS Feeds: Home 2015-05-21 22:24:00     news    politics
# 9            Daily Nation | Home 2015-08-28 20:57:00     news    politics
# 11           Daily Nation | Home 2015-08-28 21:22:00     news    politics
# 15           Daily Nation | Home 2015-08-28 21:28:00     news    politics
# 16           Daily Nation | Home 2015-08-28 21:34:00     news    politics

# %% [markdown]
# ### Add sentiment column

# %%
news['sentiment'] = news['headline'].apply(getSentiment)
news.describe()
# Out:
#                             date  \
# count                       4310
# unique                      3877
# top     July 24, 2014 at 03:00AM
# freq                          14
# first                        NaN
# last                         NaN
#
#                                                  headline  \
# count                                                4301
# unique                                               4248
# top     Taxpayers to pay twice as two teams of MPs pro...
# freq                                                    4
# first                                                 NaN
# last                                                  NaN
#
#                                                 paragraph  \
# count                                                4302
# unique                                               4257
# top     While the parallel meetings are likely to offe...
# freq                                                    4
# first                                                 NaN
# last                                                  NaN
#
#                                                       url  \
# count                                                4310
# unique                                               4290
# top     http://www.nation.co.ke/news/politics/Taxpayer...
# freq                                                    4
# first                                                 NaN
# last                                                  NaN
#
#                               source             datetime category  \
# count                           4310                 4310     4310
# unique                             2                 3877        1
# top     Daily Nation RSS Feeds: Home  2014-07-24 03:00:00     news
# freq                            3925                   14     4310
# first                            NaN  2013-09-05 10:56:00      NaN
# last                             NaN  2015-10-13 12:14:00      NaN
#
#        subCategory sentiment
# count         4310      4310
# unique           1       173
# top       politics       0.0
# freq          4310      1987
# first          NaN       NaN
# last           NaN       NaN

# %% [markdown]
# ### Filter to November 2014 / December 2014

# %%
news2014 = news.copy()[news.copy().apply(lambda x: '2014' in x['date'] and 'november' in x['date'].lower() and float(x['sentiment']) != 0, axis=1)]
news2015 = news.copy()[news.copy().apply(lambda x: '2014' in x['date'] and 'december' in x['date'].lower() and float(x['sentiment']) != 0, axis=1)]
news2015.tail()
# Out:
#                                date  \
# 56221  December 15, 2014 at 09:31PM
# 56241  December 15, 2014 at 09:40PM
# 56285  December 16, 2014 at 06:04PM
# 56332  December 16, 2014 at 09:54PM
# 56337  December 16, 2014 at 10:05PM
#
#                                                 headline  \
# 56221           Shots fired, panic as ODM poll disrupted
# 56241            Lobbies pile up pressure on police Bill
# 56285  ICC case against Uhuru Kenyatta prevented viol...
# 56332  Teams on new security laws meet to write the f...
# 56337  Showdown looms as Cord plots Parliament siege ...
#
#                                                paragraph  \
# 56221  Disruption of the Homa Bay Senate nominations ...
# 56241  A parliamentary committee was Monday under pre...
# 56285  Indictment for crimes against humanity created...
# 56332  Committees drafting amendments to the controve...
# 56337  Opposition politicians have vowed to seal off ...
#
#                                                      url  \
# 56221  http://www.nation.co.ke/news/politics/Shots-fi...
# 56241  http://www.nation.co.ke/news/politics/Lobbies-...
# 56285  http://www.nation.co.ke/news/politics/Luis-Mor...
# 56332  http://www.nation.co.ke/news/politics/Teams-on...
# 56337  http://www.nation.co.ke/news/politics/Showdown...
#
#                              source            datetime category subCategory  \
# 56221  Daily Nation RSS Feeds: Home 2014-12-15 21:31:00     news    politics
# 56241  Daily Nation RSS Feeds: Home 2014-12-15 21:40:00     news    politics
# 56285  Daily Nation RSS Feeds: Home 2014-12-16 18:04:00     news    politics
# 56332  Daily Nation RSS Feeds: Home 2014-12-16 21:54:00     news    politics
# 56337  Daily Nation RSS Feeds: Home 2014-12-16 22:05:00     news    politics
#
#       sentiment
# 56221   -0.7845
# 56241    -0.296
# 56285   -0.6124
# 56332      0.34
# 56337   -0.5423

# %%
list_of_datetimes2014 = [int(parse(x).day) for x in news2014['date']]
list_of_datetimes2015 = [int(parse(x).day) for x in news2015['date']]
#dates2014 = matplotlib.dates.date2num(list_of_datetimes2014)
#dates2015 = matplotlib.dates.date2num(list_of_datetimes2015)\

# %% [markdown]
# ### Plot

# %%
fig = plt.figure(figsize=(12, 5), dpi=100)
ax = fig.gca()
#plt.plot_date(list_of_datetimes2014, news2014['sentiment'],'ro')
#plt.plot_date(list_of_datetimes2015, news2015['sentiment'],'bx')
plt.plot(list_of_datetimes2014, news2014['sentiment'],'bo')
plt.plot(list_of_datetimes2015, news2015['sentiment'],'ro')
plt.axhline(0, linewidth=2, color='black')
plt.xlabel("Day of Month")
fig.suptitle('POLITICAL SENTIMENT', fontsize=15)
plt.ylabel("Sentiment")
plt.grid()
plt.show()
print("Daily Nation news headlines dataset:")
print("Avarage sentiment(November 2014): \t",round(np.array([float(x) for x in news2014['sentiment']]).mean(), 2))
print("Avarage sentiment(December 2014): \t",round(np.array([float(x) for x in news2015['sentiment']]).mean(), 2))
# Out:
# Daily Nation news headlines dataset:
# Avarage sentiment(November 2014): 	 -0.17
# Avarage sentiment(December 2014): 	 -0.02
